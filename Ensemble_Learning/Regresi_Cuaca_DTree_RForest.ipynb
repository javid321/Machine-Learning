# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv('dataset/london_weather.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
data_df
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101         2.00      7.00             52.00      2.30      -4.10
# 1      19790102         6.00      1.70             27.00      1.60      -2.60
# 2      19790103         5.00      0.00             13.00      1.30      -2.80
# 3      19790104         8.00      0.00             13.00     -0.30      -2.60
# 4      19790105         6.00      2.00             29.00      5.60      -0.80
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227         1.00      0.90             32.00      7.50       7.50
# 15337  20201228         7.00      3.70             38.00      3.60       1.10
# 15338  20201229         7.00      0.00             21.00      4.10       2.60
# 15339  20201230         6.00      0.40             22.00      5.60       2.70
# 15340  20201231         7.00      1.30             34.00      1.50      -0.80
#
# ...

# %%
sorted(data_df['date'].unique())
# Out:
# [19790101,
#  19790102,
#  19790103,
#  19790104,
#  19790105,
#  19790106,
#  19790107,
#  19790108,
#  19790109,
#  19790110,
#  19790111,
#  19790112,
#  19790113,
#  19790114,
#  19790115,
#  19790116,
#  19790117,
#  19790118,
#  19790119,
#  19790120,
#  19790121,
#  19790122,
#  19790123,
#  19790124,
#  19790125,
#  19790126,
#  19790127,
#  19790128,
#  19790129,
#  19790130,
#  19790131,
#  19790201,
#  19790202,
#  19790203,
#  19790204,
#  19790205,
#  19790206,
#  19790207,
#  19790208,
#  19790209,
#  19790210,
#  19790211,
#  19790212,
#  19790213,
#  19790214,
#  19790215,
#  19790216,
#  19790217,
#  19790218,
#  19790219,
#  19790220,
#  19790221,
#  19790222,
#  19790223,
#  19790224,
#  19790225,
#  19790226,
#  19790227,
#  19790228,
#  19790301,
#  19790302,
#  19790303,
#  19790304,
#  19790305,
#  19790306,
#  19790307,
#  19790308,
#  19790309,
#  19790310,
#  19790311,
#  19790312,
#  19790313,
#  19790314,
#  19790315,
#  19790316,
#  19790317,
# ...

# %%
data_df['date'] = pd.to_datetime(data_df['date'], format='%Y%m%d')

# %% [markdown]
# # EDA

# %%
data_df.head().style.highlight_null(color='yellow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e883_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_5e883_level0_col1" class="col_heading level0 col1" >cloud_cover</th>
#       <th id="T_5e883_level0_col2" class="col_heading level0 col2" >sunshine</th>
#       <th id="T_5e883_level0_col3" class="col_heading level0 col3" >global_radiation</th>
#       <th id="T_5e883_level0_col4" class="col_heading level0 col4" >max_temp</th>
#       <th id="T_5e883_level0_col5" class="col_heading level0 col5" >mean_temp</th>
#       <th id="T_5e883_level0_col6" class="col_heading level0 col6" >min_temp</th>
#       <th id="T_5e883_level0_col7" class="col_heading level0 col7" >precipitation</th>
#       <th id="T_5e883_level0_col8" class="col_heading level0 col8" >pressure</th>
#       <th id="T_5e883_level0_col9" class="col_heading level0 col9" >snow_depth</th>
#     </tr>
# ...

# %%
data_df.shape
# Out:
# (15341, 10)

# %%
data_df.describe()
# Out:
#                       date  cloud_cover  sunshine  global_radiation  max_temp  \
# count                15341     15322.00  15341.00          15322.00  15335.00
# mean   2000-01-01 00:00:00         5.27      4.35            118.76     15.39
# min    1979-01-01 00:00:00         0.00      0.00              8.00     -6.20
# 25%    1989-07-02 00:00:00         4.00      0.50             41.00     10.50
# 50%    2000-01-01 00:00:00         6.00      3.50             95.00     15.00
# 75%    2010-07-02 00:00:00         7.00      7.20            186.00     20.30
# max    2020-12-31 00:00:00         9.00     16.00            402.00     37.90
# std                    NaN         2.07      4.03             88.90      6.55
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth
# count   15305.00  15339.00       15335.00  15337.00    13900.00
# mean       11.48      7.56           1.67 101536.61        0.04
# min        -7.60    -11.80           0.00  95960.00        0.00
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  datetime64[ns]
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 1.2 MB

# %%
data_df.isnull().any().value_counts() # kolomnya
# Out:
# True     8
# False    2
# Name: count, dtype: int64

# %%
print(data_df.isnull().sum().sum())
print(type(data_df.isnull().sum().sum()))
# Out:
# 1533
# <class 'numpy.int64'>

# %%
jumlah_null = data_df.isnull().sum()
jumlah_null
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64

# %%
'''
#jika ada 2 atau lebih null atau nan sebaris, oleh pandas baris tersebut ditampilkan sebanyak 
#jumlah null atau nan yang ada pada baris tersebut. oleh karena itu kita gunakan drop_duplicate()
'''

data_df[data_df.isnull().values].drop_duplicates()[:20].style.highlight_null(color='green')
# Out:
# <style type="text/css">
# #T_5f41f_row0_col1, #T_5f41f_row1_col1, #T_5f41f_row2_col1, #T_5f41f_row3_col1, #T_5f41f_row4_col1, #T_5f41f_row5_col1, #T_5f41f_row6_col1, #T_5f41f_row7_col1, #T_5f41f_row8_col1, #T_5f41f_row9_col1, #T_5f41f_row10_col8, #T_5f41f_row11_col1, #T_5f41f_row12_col1, #T_5f41f_row13_col1, #T_5f41f_row14_col1, #T_5f41f_row15_col3, #T_5f41f_row16_col3, #T_5f41f_row17_col3, #T_5f41f_row18_col3, #T_5f41f_row19_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_5f41f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f41f_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_5f41f_level0_col1" class="col_heading level0 col1" >cloud_cover</th>
#       <th id="T_5f41f_level0_col2" class="col_heading level0 col2" >sunshine</th>
#       <th id="T_5f41f_level0_col3" class="col_heading level0 col3" >global_radiation</th>
# ...

# %%
list_kolomnull = data_df.columns[data_df.isnull().any()]
list_kolomnull
# Out:
# Index(['cloud_cover', 'global_radiation', 'max_temp', 'mean_temp', 'min_temp',
#        'precipitation', 'pressure', 'snow_depth'],
#       dtype='object')

# %%
mean_kolom = {x: round(data_df[x].mean(), 2) for x in list_kolomnull}
mean_kolom
# Out:
# {'cloud_cover': 5.27,
#  'global_radiation': 118.76,
#  'max_temp': 15.39,
#  'mean_temp': 11.48,
#  'min_temp': 7.56,
#  'precipitation': 1.67,
#  'pressure': 101536.61,
#  'snow_depth': 0.04}

# %%
import copy

# %%
dataclean_df = copy.deepcopy(data_df)
dataclean_df.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01         2.00      7.00             52.00      2.30      -4.10
# 1 1979-01-02         6.00      1.70             27.00      1.60      -2.60
# 2 1979-01-03         5.00      0.00             13.00      1.30      -2.80
# 3 1979-01-04         8.00      0.00             13.00     -0.30      -2.60
# 4 1979-01-05         6.00      2.00             29.00      5.60      -0.80
#
#    min_temp  precipitation  pressure  snow_depth
# 0     -7.50           0.40 101900.00        9.00
# 1     -7.50           0.00 102530.00        8.00
# 2     -7.20           0.00 102050.00        4.00
# 3     -6.50           0.00 100840.00        2.00
# 4     -1.40           0.00 102250.00        1.00

# %%
for col, mean in mean_kolom.items():
    dataclean_df[str(col)] = dataclean_df[str(col)].fillna(value=mean)

# %%
dataclean_df.isnull().any().value_counts() # kolomnya
# Out:
# False    10
# Name: count, dtype: int64

# %%
jumlah_null = dataclean_df.isnull().sum()
jumlah_null
# Out:
# date                0
# cloud_cover         0
# sunshine            0
# global_radiation    0
# max_temp            0
# mean_temp           0
# min_temp            0
# precipitation       0
# pressure            0
# snow_depth          0
# dtype: int64

# %%
dataclean_df[dataclean_df.isnull().values].drop_duplicates()[:20].style.highlight_null(color='green')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bcfe3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcfe3_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_bcfe3_level0_col1" class="col_heading level0 col1" >cloud_cover</th>
#       <th id="T_bcfe3_level0_col2" class="col_heading level0 col2" >sunshine</th>
#       <th id="T_bcfe3_level0_col3" class="col_heading level0 col3" >global_radiation</th>
#       <th id="T_bcfe3_level0_col4" class="col_heading level0 col4" >max_temp</th>
#       <th id="T_bcfe3_level0_col5" class="col_heading level0 col5" >mean_temp</th>
#       <th id="T_bcfe3_level0_col6" class="col_heading level0 col6" >min_temp</th>
#       <th id="T_bcfe3_level0_col7" class="col_heading level0 col7" >precipitation</th>
#       <th id="T_bcfe3_level0_col8" class="col_heading level0 col8" >pressure</th>
#       <th id="T_bcfe3_level0_col9" class="col_heading level0 col9" >snow_depth</th>
#     </tr>
# ...

# %%
dataclean_df.shape
# Out:
# (15341, 10)

# %%
dataclean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  datetime64[ns]
#  1   cloud_cover       15341 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15341 non-null  float64
#  4   max_temp          15341 non-null  float64
#  5   mean_temp         15341 non-null  float64
#  6   min_temp          15341 non-null  float64
#  7   precipitation     15341 non-null  float64
#  8   pressure          15341 non-null  float64
#  9   snow_depth        15341 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 1.2 MB

# %%
dataclean_df.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01         2.00      7.00             52.00      2.30      -4.10
# 1 1979-01-02         6.00      1.70             27.00      1.60      -2.60
# 2 1979-01-03         5.00      0.00             13.00      1.30      -2.80
# 3 1979-01-04         8.00      0.00             13.00     -0.30      -2.60
# 4 1979-01-05         6.00      2.00             29.00      5.60      -0.80
#
#    min_temp  precipitation  pressure  snow_depth
# 0     -7.50           0.40 101900.00        9.00
# 1     -7.50           0.00 102530.00        8.00
# 2     -7.20           0.00 102050.00        4.00
# 3     -6.50           0.00 100840.00        2.00
# 4     -1.40           0.00 102250.00        1.00

# %% [markdown]
# # Feature Engineering

# %%
dataclean_df['year'] = dataclean_df['date'].dt.year
dataclean_df['month'] = dataclean_df['date'].dt.month
dataclean_df['day'] = dataclean_df['date'].dt.day

# %%
dataclean_df.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01         2.00      7.00             52.00      2.30      -4.10
# 1 1979-01-02         6.00      1.70             27.00      1.60      -2.60
# 2 1979-01-03         5.00      0.00             13.00      1.30      -2.80
# 3 1979-01-04         8.00      0.00             13.00     -0.30      -2.60
# 4 1979-01-05         6.00      2.00             29.00      5.60      -0.80
#
#    min_temp  precipitation  pressure  snow_depth  year  month  day
# 0     -7.50           0.40 101900.00        9.00  1979      1    1
# 1     -7.50           0.00 102530.00        8.00  1979      1    2
# 2     -7.20           0.00 102050.00        4.00  1979      1    3
# 3     -6.50           0.00 100840.00        2.00  1979      1    4
# 4     -1.40           0.00 102250.00        1.00  1979      1    5

# %%
dataclean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  datetime64[ns]
#  1   cloud_cover       15341 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15341 non-null  float64
#  4   max_temp          15341 non-null  float64
#  5   mean_temp         15341 non-null  float64
#  6   min_temp          15341 non-null  float64
#  7   precipitation     15341 non-null  float64
#  8   pressure          15341 non-null  float64
#  9   snow_depth        15341 non-null  float64
#  10  year              15341 non-null  int32
#  11  month             15341 non-null  int32
#  12  day               15341 non-null  int32
# dtypes: datetime64[ns](1), float64(9), int32(3)
# memory usage: 1.3 MB

# %%
sns.scatterplot(x= dataclean_df['month'], y=dataclean_df['snow_depth'], hue=dataclean_df['mean_temp'])
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper right', borderaxespad=0, title='mean_temp')

# %%
dataclean_df['snow_depth'].unique()
# Out:
# array([ 9.  ,  8.  ,  4.  ,  2.  ,  1.  ,  0.  ,  6.  ,  7.  , 22.  ,
#        20.  , 16.  , 18.  , 15.  , 13.  , 11.  , 10.  ,  3.  ,  5.  ,
#        12.  ,  0.04])

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataclean_df.drop(columns=['date', 'snow_depth'])
y = dataclean_df['snow_depth']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((12272, 11), (3069, 11), (12272,), (3069,))

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model_dtree = DecisionTreeRegressor()
model_rforest = RandomForestRegressor()

# %%
model_dtree.fit(X_train, y_train)
model_rforest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model_dtree.score(X_train, y_train), model_dtree.score(X_test, y_test)
# Out:
# (1.0, 0.275645897428647)

# %%
model_rforest.score(X_train, y_train), model_rforest.score(X_test, y_test)
# Out:
# (0.9194905438169902, 0.4406369289142771)

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipeline=Pipeline([
    ('model_clf', RandomForestRegressor(n_jobs=-1))
])

# %% [markdown]
# # GidSearcV

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('model_clf', RandomForestRegressor(n_jobs=-1, random_state=42))],
#  'verbose': False,
#  'model_clf': RandomForestRegressor(n_jobs=-1, random_state=42),
#  'model_clf__bootstrap': True,
#  'model_clf__ccp_alpha': 0.0,
#  'model_clf__criterion': 'squared_error',
#  'model_clf__max_depth': None,
#  'model_clf__max_features': 1.0,
#  'model_clf__max_leaf_nodes': None,
#  'model_clf__max_samples': None,
#  'model_clf__min_impurity_decrease': 0.0,
#  'model_clf__min_samples_leaf': 1,
#  'model_clf__min_samples_split': 2,
#  'model_clf__min_weight_fraction_leaf': 0.0,
#  'model_clf__monotonic_cst': None,
#  'model_clf__n_estimators': 100,
#  'model_clf__n_jobs': -1,
#  'model_clf__oob_score': False,
#  'model_clf__random_state': 42,
#  'model_clf__verbose': 0,
#  'model_clf__warm_start': False}

# %%
parameter = {
    'model_clf__n_estimators': [100, 150],
    'model_clf__max_depth': [20, 50, 80],
    'model_clf__max_features' : [0.3, 0.6, 0.8],
    'model_clf__min_samples_leaf':[1, 5, 10]
}

# %%
model_grid = GridSearchCV(model_pipeline, parameter, cv= 3, n_jobs=-1, verbose=1)

# %%
model_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('model_clf',
#                                         RandomForestRegressor(n_jobs=-1,
#                                                               random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model_clf__max_depth': [20, 50, 80],
#                          'model_clf__max_features': [0.3, 0.6, 0.8],
#                          'model_clf__min_samples_leaf': [1, 5, 10],
#                          'model_clf__n_estimators': [100, 150]},
#              verbose=1)

# %%
pd.DataFrame(model_grid.cv_results_).sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13           6.91          0.17             1.61            0.08
# 31           7.67          0.44             1.11            0.57
# 49           6.53          0.04             1.17            0.05
# 7            5.63          0.26             1.66            0.27
# 43           5.88          0.08             1.17            0.38
# 25           5.78          0.25             1.24            0.13
# 12           4.43          0.28             1.22            0.08
# 30           4.69          0.38             1.07            0.26
# 48           4.60          0.26             1.18            0.14
# 6            3.59          0.20             1.08            0.15
# 42           3.82          0.20             0.79            0.38
# 24           3.45          0.50             1.42            0.68
# 37           3.75          0.10             1.08            0.35
# ...

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score
 
# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')
 
# Making predictions on the same data or new data
predictions = regressor.predict(x)
 
# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')
 
r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
